# %%
import yfinance as yf

t = yf.Ticker("PAT.DE")

info = t.info

# %%
d = info['exDividendDate']

# %%
info
# Out:
# {'address1': 'Fuggerstrasse 26',
#  'city': 'Augsburg',
#  'zip': '86150',
#  'country': 'Germany',
#  'phone': '49 821 5091 0000',
#  'fax': '49 821 5091 0999',
#  'website': 'https://www.patrizia.ag',
#  'industry': 'Real Estate Services',
#  'industryDisp': 'Real Estate Services',
#  'sector': 'Real Estate',
# ...
